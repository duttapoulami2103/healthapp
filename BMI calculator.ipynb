# %%
#BMI CALCULATOR without AI

name=input("enter your name")
weight=float(input("enter your weight"))
height=float(input("enter your height"))
bmi=weight/((height)**2)
print(f"{name},your bmi is{bmi}")
# Out:
# enter your name pia
# enter your weight 56
# enter your height 5
# pia,your bmi is2.24

# %%
#BMI calculator with AI

import google.generativeai as genai
genai.configure(api_key="AIzaSyDuI2XIIzTwmg2pLn0nTPJmg0JktOd9nLA")
model=genai.GenerativeModel("gemini-2.5-flash")

# %%
name=input("enter your name")
weight=float(input("enter your weight"))
height=float(input("enter your height"))
bmi=weight/((height)**2)
print(f"{name},your bmi is{bmi}")

# %%
prompt= f"with height{height}, weight {weight}, bmi as {bmi}, comment as nutitionist"
response=model.generate_content(prompt)
print(response.text)
# Out:
# Thank you for providing these details. As a nutritionist, here's my assessment and recommendations:
#
# **Assessment:**
#
# *   **Height:** 1.5 meters (4 feet 11 inches)
# *   **Weight:** 62.0 kg (136.7 lbs)
# *   **BMI:** 27.56 (rounding the decimal)
#
# Based on standard classifications for adults, a BMI between 25.0 and 29.9 falls into the **"Overweight"** category.
#
# **Nutritionist's Comment:**
#
# "Based on your height of 1.5m and weight of 62.0kg, your calculated Body Mass Index (BMI) is approximately 27.6. This places you in the **"Overweight"** category according to international standards.
#
# While BMI is a useful screening tool, it's important to remember it doesn't tell the whole story about an individual's health or body composition. Factors like muscle mass, body fat distribution (e.g., waist circumference), age, and overall health status also play a significant role.
#
# However, being in the overweight category does suggest an increased risk for various health conditions over time, such as:
#
# *   Type 2 diabetes
# *   Heart disease and high blood pressure
# *   Certain cancers
# *   Osteoarthritis
# *   Sleep apnea
#
# This is an excellent opportunity to focus on sustainable health improvements. My primary recommendation would be to aim for a gradual and healthy weight management strategy, focusing on building sustainable lifestyle habits rather than just 'losing weight quickly.'
#
# **Here are some key areas to consider:**
#
# 1.  **Balanced Nutrition:**
#     *   **Focus on Whole Foods:** Prioritize fruits, vegetables, lean proteins (chicken, fish, beans, lentils, tofu), whole grains (brown rice, quinoa, whole-wheat bread), and healthy fats (avocado, nuts, seeds, olive oil).
#     *   **Limit Processed Foods:** Reduce intake of sugary drinks, fast food, highly processed snacks, and foods high in unhealthy saturated and trans fats.
#     *   **Portion Control:** Pay attention to portion sizes to ensure you're consuming appropriate amounts for your energy needs.
#     *   **Hydration:** Drink plenty of water throughout the day.
#
# 2.  **Regular Physical Activity:**
#     *   Aim for at least 150 minutes of moderate-intensity aerobic activity (like brisk walking, cycling, swimming) per week, or 75 minutes of vigorous-intensity activity.
#     *   Incorporate strength training exercises 2-3 times per week to build muscle mass, which can boost metabolism.
#     *   Look for opportunities to move more throughout your day – take the stairs, walk during breaks, stand while working.
#
# 3.  **Lifestyle Factors:**
#     *   **Adequate Sleep:** Aim for 7-9 hours of quality sleep per night, as poor sleep can impact hormones related to hunger and metabolism.
#     *   **Stress Management:** Find healthy ways to manage stress, as chronic stress can also affect weight.
#
# **Next Steps:**
#
# I highly recommend consulting with a healthcare professional, such as your General Practitioner, and/or a Registered Dietitian. They can provide a personalized assessment, take into account your full medical history, conduct further health screenings, and help you develop a tailored, safe, and effective plan to achieve a healthier weight and improve your overall well-being. The goal is to move towards a healthy weight range (which for your height, would typically be a BMI between 18.5 and 24.9) through sustainable and enjoyable habits."
